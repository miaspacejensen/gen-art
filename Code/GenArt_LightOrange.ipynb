# %%
import sys
import os
from pathlib import Path

sys.path.append("Modules")
import genart_modules as gam

# %%
cwd = os.getcwd()
cwd_parent = str(Path(cwd).parent.absolute())

# %%
grid_size_x = grid_size_y = 75
dot_size_range = (1, 10) 
step_size = 5
lim = 8
num_plots = 1
col1="#ffc876" # #FF9800
col2="#EE578a" # #f8bbd0 
export_path = cwd_parent + "\\Output\\Light Orange"

# %%
for i in range(num_plots): 
    mat1 = gam.build_dot_size_matrix(grid_size_x, grid_size_y, dot_size_range, step_size=5)
    mat2 = gam.build_dot_size_matrix(grid_size_x, grid_size_y, dot_size_range, step_size=5)
    gam.plot_grid_overlay(mat1, mat2, grid_size_x, grid_size_y, linewidth=1, alpha=1, col1=col1, col2=col2, lim=lim, export_path=export_path)
# Out:
# 17090878415162067_GetArt
